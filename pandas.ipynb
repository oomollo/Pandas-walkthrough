# %%
import pandas as pd

# %%
df = pd.read_json(r"C:\Users\Olgah\Documents\Moringaprojects\DS-PT11\phase1\Pandas\Data\Students_Grading_Dataset.json")
df.head()
# Out:
#   Student_ID First_Name Last_Name                    Email  Gender  Age  \
# 0      S1000       Omar  Williams  student0@university.com  Female   22
# 1      S1001      Maria     Brown  student1@university.com    Male   18
# 2      S1002      Ahmed     Jones  student2@university.com    Male   24
# 3      S1003       Omar  Williams  student3@university.com  Female   24
# 4      S1004       John     Smith  student4@university.com  Female   23
#
#     Department  Attendance (%)  Midterm_Score  Final_Score  ...  \
# 0  Engineering           52.29          55.03        57.82  ...
# 1  Engineering           97.27          97.23        45.80  ...
# 2     Business           57.19          67.05        93.68  ...
# 3  Mathematics           95.15          47.79        80.63  ...
# 4           CS           54.18          46.59        78.89  ...
#
#    Projects_Score  Total_Score  Grade  Study_Hours_per_Week  \
# 0           85.90        56.09      F                   6.2
# ...

# %%
df= pd.read_csv(r"C:\Users\Olgah\Documents\Moringaprojects\DS-PT11\phase1\Pandas\Data\Students_Grading_Dataset.csv")
df.head()
# Out:
#   Student_ID First_Name Last_Name                    Email  Gender  Age  \
# 0      S1000       Omar  Williams  student0@university.com  Female   22
# 1      S1001      Maria     Brown  student1@university.com    Male   18
# 2      S1002      Ahmed     Jones  student2@university.com    Male   24
# 3      S1003       Omar  Williams  student3@university.com  Female   24
# 4      S1004       John     Smith  student4@university.com  Female   23
#
#     Department  Attendance (%)  Midterm_Score  Final_Score  ...  \
# 0  Engineering           52.29          55.03        57.82  ...
# 1  Engineering           97.27          97.23        45.80  ...
# 2     Business           57.19          67.05        93.68  ...
# 3  Mathematics           95.15          47.79        80.63  ...
# 4           CS           54.18          46.59        78.89  ...
#
#    Projects_Score  Total_Score  Grade  Study_Hours_per_Week  \
# 0           85.90        56.09      F                   6.2
# ...

# %%
#creating a pandas series
Student_IDs= df['Student_ID']
Student_IDs
# Out:
# 0       S1000
# 1       S1001
# 2       S1002
# 3       S1003
# 4       S1004
#         ...
# 4995    S5995
# 4996    S5996
# 4997    S5997
# 4998    S5998
# 4999    S5999
# Name: Student_ID, Length: 5000, dtype: object

# %%
Student_ages= df['Age']
Student_ages
# Out:
# 0       22
# 1       18
# 2       24
# 3       24
# 4       23
#         ..
# 4995    19
# 4996    19
# 4997    24
# 4998    23
# 4999    21
# Name: Age, Length: 5000, dtype: int64

# %%
# first 5 columns
df['Age'].head()
# Out:
# 0    22
# 1    18
# 2    24
# 3    24
# 4    23
# Name: Age, dtype: int64

# %%
#last 5 items on age colum
df['Age'].tail(5)
# Out:
# 4995    19
# 4996    19
# 4997    24
# 4998    23
# 4999    21
# Name: Age, dtype: int64

# %%
# summary statistics
summary_stats= df.describe()
summary_stats
# Out:
#                Age  Attendance (%)  Midterm_Score  Final_Score  \
# count  5000.000000     4484.000000    5000.000000  5000.000000
# mean     21.048400       75.431409      70.326844    69.640788
# std       1.989786       14.372446      17.213209    17.238744
# min      18.000000       50.010000      40.000000    40.000000
# 25%      19.000000       63.265000      55.457500    54.667500
# 50%      21.000000       75.725000      70.510000    69.735000
# 75%      23.000000       87.472500      84.970000    84.500000
# max      24.000000      100.000000      99.980000    99.980000
#
#        Assignments_Avg  Quizzes_Avg  Participation_Score  Projects_Score  \
# count      4483.000000  5000.000000          5000.000000     5000.000000
# mean         74.798673    74.910728             4.980024       74.924860
# std          14.411799    14.504281             2.890136       14.423415
# min          50.000000    50.030000             0.000000       50.010000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 23 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Student_ID                  5000 non-null   object
#  1   First_Name                  5000 non-null   object
#  2   Last_Name                   5000 non-null   object
#  3   Email                       5000 non-null   object
#  4   Gender                      5000 non-null   object
#  5   Age                         5000 non-null   int64
#  6   Department                  5000 non-null   object
#  7   Attendance (%)              4484 non-null   float64
#  8   Midterm_Score               5000 non-null   float64
#  9   Final_Score                 5000 non-null   float64
#  10  Assignments_Avg             4483 non-null   float64
#  11  Quizzes_Avg                 5000 non-null   float64
#  12  Participation_Score         5000 non-null   float64
# ...

# %%
mean_age= df['Age'].mean
median_age = df['Age'].median
sum_age= df['Age'].sum
count_age= df['Age'].count
mean_age
median_age
sum_age
count_age
# Out:
# <bound method Series.count of 0       22
# 1       18
# 2       24
# 3       24
# 4       23
#         ..
# 4995    19
# 4996    19
# 4997    24
# 4998    23
# 4999    21
# Name: Age, Length: 5000, dtype: int64>

# %%
# reseting index
df.set_index(['Student_ID'])
# Out:
#            First_Name Last_Name                       Email  Gender  Age  \
# Student_ID
# S1000            Omar  Williams     student0@university.com  Female   22
# S1001           Maria     Brown     student1@university.com    Male   18
# S1002           Ahmed     Jones     student2@university.com    Male   24
# S1003            Omar  Williams     student3@university.com  Female   24
# S1004            John     Smith     student4@university.com  Female   23
# ...               ...       ...                         ...     ...  ...
# S5995           Ahmed     Jones  student4995@university.com    Male   19
# S5996            Emma     Brown  student4996@university.com    Male   19
# S5997            John     Brown  student4997@university.com  Female   24
# S5998            Sara     Davis  student4998@university.com    Male   23
# S5999           Maria     Brown  student4999@university.com  Female   21
#
#              Department  Attendance (%)  Midterm_Score  Final_Score  \
# ...

# %%
#changing data type
df['Age']=df['Age'].astype(object)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 23 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Student_ID                  5000 non-null   object
#  1   First_Name                  5000 non-null   object
#  2   Last_Name                   5000 non-null   object
#  3   Email                       5000 non-null   object
#  4   Gender                      5000 non-null   object
#  5   Age                         5000 non-null   object
#  6   Department                  5000 non-null   object
#  7   Attendance (%)              4484 non-null   float64
#  8   Midterm_Score               5000 non-null   float64
#  9   Final_Score                 5000 non-null   float64
#  10  Assignments_Avg             4483 non-null   float64
#  11  Quizzes_Avg                 5000 non-null   float64
#  12  Participation_Score         5000 non-null   float64
# ...

# %%
#.map() and .apply() method
#.map()used to apply fuction to each element in pandas series
# e,g Gender
df_gender= df['Gender'].map( {'Male':0,'Female':1} )
df_gender
# Out:
# 0       1
# 1       0
# 2       0
# 3       1
# 4       1
#        ..
# 4995    0
# 4996    0
# 4997    1
# 4998    0
# 4999    1
# Name: Gender, Length: 5000, dtype: int64

# %%
engineering_dpt = df[df['Department']=='Engineering']
engineering_dpt
# Out:
#      Student_ID First_Name Last_Name                       Email  Gender Age  \
# 0         S1000       Omar  Williams     student0@university.com  Female  22
# 1         S1001      Maria     Brown     student1@university.com    Male  18
# 5         S1005       Liam     Brown     student5@university.com    Male  21
# 7         S1007      Ahmed     Smith     student7@university.com    Male  19
# 9         S1009       Sara     Smith     student9@university.com  Female  22
# ...         ...        ...       ...                         ...     ...  ..
# 4984      S5984       Liam   Johnson  student4984@university.com  Female  20
# 4988      S5988       John     Smith  student4988@university.com  Female  19
# 4989      S5989       Liam     Brown  student4989@university.com    Male  23
# 4991      S5991       John  Williams  student4991@university.com  Female  20
# 4999      S5999      Maria     Brown  student4999@university.com  Female  21
#
# ...

# %%
#.apply()- used on dataframes,similar as .map()- used to apply a function on either rows or collums. allows for more complex operations
def calculate_total(row):
    return row['Midterm_Score'] + row['Final_Score'] + row['Assignments_Avg'] +row['Participation_Score'] + row['Projects_Score']
df['Total_Score'] = df.apply(calculate_total, axis=1)
df['Total_Score']
# Out:
# 0       286.96
# 1          NaN
# 2       307.27
# 3       293.14
# 4       296.72
#          ...
# 4995    285.99
# 4996       NaN
# 4997    307.82
# 4998    349.96
# 4999    258.21
# Name: Total_Score, Length: 5000, dtype: float64

# %%
# a
def calculate_average(row):
    return (row['Midterm_Score'] + row['Final_Score'] + row['Assignments_Avg'] +row['Participation_Score'] + row['Projects_Score']+ row['Attendance (%)'])/6
df['Avg_Score'] = df.apply(calculate_average, axis=1)
df['Avg_Score']
# Out:
# 0       56.541667
# 1             NaN
# 2       60.743333
# 3       64.715000
# 4       58.483333
#           ...
# 4995          NaN
# 4996          NaN
# 4997    65.893333
# 4998    73.753333
# 4999    57.021667
# Name: Avg_Score, Length: 5000, dtype: float64

# %%
df['Avg_Score']= df['Avg_Score'].map( {} )
df['Avg_Score']
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#         ..
# 4995   NaN
# 4996   NaN
# 4997   NaN
# 4998   NaN
# 4999   NaN
# Name: Avg_Score, Length: 5000, dtype: float64

# %%
# LAMBDA functions

# %%
df['Age']= df['Age']

# %%
df= df.applymap(lambda x: round(x, 1) if isinstance (x, (float)) else x)
df.head()
# Out:
#   Student_ID First_Name Last_Name                    Email  Gender  Age  \
# 0      S1000       Omar  Williams  student0@university.com  Female   22
# 1      S1001      Maria     Brown  student1@university.com    Male   18
# 2      S1002      Ahmed     Jones  student2@university.com    Male   24
# 3      S1003       Omar  Williams  student3@university.com  Female   24
# 4      S1004       John     Smith  student4@university.com  Female   23
#
#     Department  Attendance (%)  Midterm_Score  Final_Score  ...  Total_Score  \
# 0  Engineering            52.3           55.0         57.8  ...        287.0
# 1  Engineering            97.3           97.2         45.8  ...          NaN
# 2     Business            57.2           67.0         93.7  ...        307.3
# 3  Mathematics            95.2           47.8         80.6  ...        293.1
# 4           CS            54.2           46.6         78.9  ...        296.7
#
#    Grade  Study_Hours_per_Week  Extracurricular_Activities  \
# ...

# %%
# use .map(), .mapapply(), Lambda functions()to manipulate this df

# %%
 # Handling Missing values in a data frame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 24 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Student_ID                  5000 non-null   object
#  1   First_Name                  5000 non-null   object
#  2   Last_Name                   5000 non-null   object
#  3   Email                       5000 non-null   object
#  4   Gender                      5000 non-null   object
#  5   Age                         5000 non-null   int64
#  6   Department                  5000 non-null   object
#  7   Attendance (%)              4484 non-null   float64
#  8   Midterm_Score               5000 non-null   float64
#  9   Final_Score                 5000 non-null   float64
#  10  Assignments_Avg             4483 non-null   float64
#  11  Quizzes_Avg                 5000 non-null   float64
#  12  Participation_Score         5000 non-null   float64
# ...

# %%
# true- for missing values, False- for actual values
df.isnull()
# Out:
#       Student_ID  First_Name  Last_Name  Email  Gender    Age  Department  \
# 0          False       False      False  False   False  False       False
# 1          False       False      False  False   False  False       False
# 2          False       False      False  False   False  False       False
# 3          False       False      False  False   False  False       False
# 4          False       False      False  False   False  False       False
# ...          ...         ...        ...    ...     ...    ...         ...
# 4995       False       False      False  False   False  False       False
# 4996       False       False      False  False   False  False       False
# 4997       False       False      False  False   False  False       False
# 4998       False       False      False  False   False  False       False
# 4999       False       False      False  False   False  False       False
#
#       Attendance (%)  Midterm_Score  Final_Score  ...  Total_Score  Grade  \
# ...

# %%
#not null=true, null- true
df.notnull()
# Out:
#       Student_ID  First_Name  Last_Name  Email  Gender   Age  Department  \
# 0           True        True       True   True    True  True        True
# 1           True        True       True   True    True  True        True
# 2           True        True       True   True    True  True        True
# 3           True        True       True   True    True  True        True
# 4           True        True       True   True    True  True        True
# ...          ...         ...        ...    ...     ...   ...         ...
# 4995        True        True       True   True    True  True        True
# 4996        True        True       True   True    True  True        True
# 4997        True        True       True   True    True  True        True
# 4998        True        True       True   True    True  True        True
# 4999        True        True       True   True    True  True        True
#
#       Attendance (%)  Midterm_Score  Final_Score  ...  Total_Score  Grade  \
# ...

# %%
# provides count of the missing values
df.isnull().sum()
# Out:
# Student_ID                       0
# First_Name                       0
# Last_Name                        0
# Email                            0
# Gender                           0
# Age                              0
# Department                       0
# Attendance (%)                 516
# Midterm_Score                    0
# Final_Score                      0
# Assignments_Avg                517
# Quizzes_Avg                      0
# Participation_Score              0
# Projects_Score                   0
# Total_Score                    517
# Grade                            0
# Study_Hours_per_Week             0
# Extracurricular_Activities       0
# Internet_Access_at_Home          0
# Parent_Education_Level         984
# Family_Income_Level              0
# Stress_Level (1-10)              0
# Sleep_Hours_per_Night            0
# Avg_Score                     5000
# dtype: int64

# %%
df.isna()
# Out:
#       Student_ID  First_Name  Last_Name  Email  Gender    Age  Department  \
# 0          False       False      False  False   False  False       False
# 1          False       False      False  False   False  False       False
# 2          False       False      False  False   False  False       False
# 3          False       False      False  False   False  False       False
# 4          False       False      False  False   False  False       False
# ...          ...         ...        ...    ...     ...    ...         ...
# 4995       False       False      False  False   False  False       False
# 4996       False       False      False  False   False  False       False
# 4997       False       False      False  False   False  False       False
# 4998       False       False      False  False   False  False       False
# 4999       False       False      False  False   False  False       False
#
#       Attendance (%)  Midterm_Score  Final_Score  ...  Total_Score  Grade  \
# ...

# %%
df.isnull().sum() / len(df) * 100
# Out:
# Student_ID                      0.00
# First_Name                      0.00
# Last_Name                       0.00
# Email                           0.00
# Gender                          0.00
# Age                             0.00
# Department                      0.00
# Attendance (%)                 10.32
# Midterm_Score                   0.00
# Final_Score                     0.00
# Assignments_Avg                10.34
# Quizzes_Avg                     0.00
# Participation_Score             0.00
# Projects_Score                  0.00
# Total_Score                    10.34
# Grade                           0.00
# Study_Hours_per_Week            0.00
# Extracurricular_Activities      0.00
# Internet_Access_at_Home         0.00
# Parent_Education_Level         19.68
# Family_Income_Level             0.00
# Stress_Level (1-10)             0.00
# Sleep_Hours_per_Night           0.00
# Avg_Score                     100.00
# dtype: float64

# %%
#drops all missing values
df.dropna()
# Out:
# Empty DataFrame
# Columns: [Student_ID, First_Name, Last_Name, Email, Gender, Age, Department, Attendance (%), Midterm_Score, Final_Score, Assignments_Avg, Quizzes_Avg, Participation_Score, Projects_Score, Total_Score, Grade, Study_Hours_per_Week, Extracurricular_Activities, Internet_Access_at_Home, Parent_Education_Level, Family_Income_Level, Stress_Level (1-10), Sleep_Hours_per_Night, Avg_Score]
# Index: []
#
# [0 rows x 24 columns]

# %%
# used to fill missing value with a particular value
df.fillna()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-62-917cebbcd6ee> in <module>
#       1 # used to fill missing value with a particular value
# ----> 2 df.fillna()
#
# c:\Users\Olgah\anaconda3\envs\learn-env\lib\site-packages\pandas\core\frame.py in fillna(self, value, method, axis, inplace, limit, downcast)
#    4315         downcast=None,
#    4316     ) -> Optional["DataFrame"]:
# -> 4317         return super().fillna(
#    4318             value=value,
#    4319             method=method,
#
# c:\Users\Olgah\anaconda3\envs\learn-env\lib\site-packages\pandas\core\generic.py in fillna(self, value, method, axis, inplace, limit, downcast)
#    6010         """
#    6011         inplace = validate_bool_kwarg(inplace, "inplace")
# -> 6012         value, method = validate_fillna_kwargs(value, method)
#    6013
# ...

# %%
df['Attendance (%)'].fillna(df['Attendance (%)'].mean(), inplace= True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 24 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Student_ID                  5000 non-null   object
#  1   First_Name                  5000 non-null   object
#  2   Last_Name                   5000 non-null   object
#  3   Email                       5000 non-null   object
#  4   Gender                      5000 non-null   object
#  5   Age                         5000 non-null   int64
#  6   Department                  5000 non-null   object
#  7   Attendance (%)              5000 non-null   float64
#  8   Midterm_Score               5000 non-null   float64
#  9   Final_Score                 5000 non-null   float64
#  10  Assignments_Avg             4483 non-null   float64
#  11  Quizzes_Avg                 5000 non-null   float64
#  12  Participation_Score         5000 non-null   float64
# ...

# %%
#Drop parent education level
# find a way that is correct to handle missing values
#  do for average score

# %%
#duplicate
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4995    False
# 4996    False
# 4997    False
# 4998    False
# 4999    False
# Length: 5000, dtype: bool

# %%
# remove duplicated values
df.dropduplicate()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-32-3e3e9fba6de7> in <module>
#       1 # remove duplicated values
# ----> 2 df.dropduplicate()
#
# c:\Users\Olgah\anaconda3\envs\learn-env\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'dropduplicate'

# %%
#.groupby()-helps agreggate data into different groups
dept_avg_score= df.groupby('Department')['Total_Score'].mean()
dept_avg_score
# Out:
# Department
# Business       294.239729
# CS             294.677029
# Engineering    294.366021
# Mathematics    294.312387
# Name: Total_Score, dtype: float64

# %%
gender_avg= df.groupby('Gender')['Final_Score'].mean()
gender_avg
# Out:
# Gender
# Female    69.586648
# Male      69.692434
# Name: Final_Score, dtype: float64

# %%
#group students by grade & calvulate the number of students in each grade
students_grade= df.groupby('Grade')['Student_ID'].count()
students_grade
# Out:
# Grade
# A    1495
# B     978
# C     794
# D     889
# F     844
# Name: Student_ID, dtype: int64

# %%
#calculate groupby dpt &gender,calculate avg attendance
avg_attendance= df.groupby(['Department','Gender'])['Attendance (%)'].mean()
avg_attendance
# Out:
# Department   Gender
# Business     Female    76.136652
#              Male      74.616304
# CS           Female    74.882508
#              Male      74.886966
# Engineering  Female    75.961965
#              Male      76.318261
# Mathematics  Female    75.714884
#              Male      75.649107
# Name: Attendance (%), dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 24 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Student_ID                  5000 non-null   object
#  1   First_Name                  5000 non-null   object
#  2   Last_Name                   5000 non-null   object
#  3   Email                       5000 non-null   object
#  4   Gender                      5000 non-null   object
#  5   Age                         5000 non-null   int64
#  6   Department                  5000 non-null   object
#  7   Attendance (%)              4484 non-null   float64
#  8   Midterm_Score               5000 non-null   float64
#  9   Final_Score                 5000 non-null   float64
#  10  Assignments_Avg             4483 non-null   float64
#  11  Quizzes_Avg                 5000 non-null   float64
#  12  Participation_Score         5000 non-null   float64
# ...

# %%
# groupby an int/float colum using a range
attendance= df.groupby('Attendance(%)')['Age'].range()
attendance
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-71-6df7414f66fe> in <module>
#       1 # groupby an int/float colum using a range
# ----> 2 attendance= df.groupby('Attendance(%)')['Age'].range()
#       3 attendance
#
# c:\Users\Olgah\anaconda3\envs\learn-env\lib\site-packages\pandas\core\frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    6509         axis = self._get_axis_number(axis)
#    6510
# -> 6511         return DataFrameGroupBy(
#    6512             obj=self,
#    6513             keys=by,
#
# c:\Users\Olgah\anaconda3\envs\learn-env\lib\site-packages\pandas\core\groupby\groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     523             from pandas.core.groupby.grouper import get_grouper
#     524
# ...

# %%
#combining Dataframe
# using concatenation
df1= pd.DataFrame({'A':[1,2,3],'B':[4,5,6]})
df2= pd.DataFrame({'A': [7,8,9],'B':[10,11,12]})
df3= pd.DataFrame({'A':[13,14,15],'B':[16,17,18]})
result= pd.concat([df1,df2,df3], axis= 0)# axis= 0 refences a row
result
# Out:
#     A   B
# 0   1   4
# 1   2   5
# 2   3   6
# 0   7  10
# 1   8  11
# 2   9  12
# 0  13  16
# 1  14  17
# 2  15  18

# %%
result= pd.concat([df1,df2,df3], axis= 1)# axis= 1 refences a columns
result
# Out:
#    A  B  A   B   A   B
# 0  1  4  7  10  13  16
# 1  2  5  8  11  14  17
# 2  3  6  9  12  15  18

# %%
#join -types of joins
#inner join-returns only records with matching keys in both tables
#outer join-returns all records,when theres a match in atleast 1 table, unmatched tables will return NaN
#left join-returns all records rom the left table and matching rows from the right table, unmstched rows will have NaN
#right join-returns all records rom the right table and matching rows from the left table, unmstched rows will have NaN

# %%
df1= pd.DataFrame({'key':['A','B','C'], 'value1':[1,2,3]})
df2= pd.DataFrame({'key':['B','C','D'], 'value2':[4,5,6]})
#innerjoin
inner_join= pd.merge(df1,df2, on='key',how='inner')
inner_join
# Out:
#   key  value1  value2
# 0   B       2       4
# 1   C       3       5

# %%
#outer join
outer_join= pd.merge(df1,df2, on='key',how='outer')
print(outer_join)
# Out:
#   key  value1  value2
# 0   A     1.0     NaN
# 1   B     2.0     4.0
# 2   C     3.0     5.0
# 3   D     NaN     6.0

# %%
#left join
left_join= pd.merge(df1,df2, on='key',how='left')
print('Left Join:\n',left_join)

#right join
right_join= pd.merge(df1,df2, on='key',how='right')
print('Right Join:\n',right_join)
# Out:
# Left Join:
#    key  value1  value2
# 0   A       1     NaN
# 1   B       2     4.0
# 2   C       3     5.0
# Right Join:
#    key  value1  value2
# 0   B     2.0       4
# 1   C     3.0       5
# 2   D     NaN       6
